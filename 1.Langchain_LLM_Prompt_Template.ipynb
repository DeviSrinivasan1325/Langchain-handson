# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# 🔑 Direct key (NOT recommended for production)
GOOGLE_API_KEY = "AIzaSyBGiWa81-vMsKZWWuPr1jsSHW2dgAF5-hQ"

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    google_api_key=GOOGLE_API_KEY
)

prompt = ChatPromptTemplate.from_template(
    "Answer clearly: {question}"
)

chain = prompt | llm

response = chain.invoke({
    "question": "What is LangGraph in LangChain?"
})

print(response.content)
# Out:
# LangGraph is a library built **on top of LangChain** specifically designed for building **stateful, multi-actor applications** using a **graph-based approach**.
#
# Here's a breakdown of what that means and its relationship to LangChain:
#
# 1.  **What it is:**
#     *   LangGraph allows you to define your LLM application as a **finite state machine (FSM)** or a **directed acyclic graph (DAG)**, where each "node" in the graph represents a step or action (e.g., calling an LLM, using a tool, human input), and "edges" define the transitions between these steps.
#     *   It manages a **shared state** that evolves as the graph executes, allowing for complex, context-aware interactions.
#
# 2.  **Why it exists (in relation to LangChain):**
#     *   While LangChain's core `Chain` and `Agent` abstractions are powerful, they can become unwieldy for scenarios requiring:
#         *   **Cycles/Loops:** Self-correction, re-planning, asking for clarification.
#         *   **Complex Branching:** Different paths based on conditions or LLM outputs.
#         *   **Human-in-the-Loop:** Pausing for user input, approval, or correction.
#         *   **Multi-Agent Collaboration:** Orchestrating multiple specialized agents that interact with each other.
#         *   **Explicit State Management:** Maintaining and updating a shared context across many steps.
#     *   LangGraph provides the **explicit structure and control** needed to build these more robust, dynamic, and complex applications that go beyond simple linear chains or basic agent loops.
#
# 3.  **How it works (briefly):**
#     *   You define **nodes**, which are typically LangChain Runnables (LLMs, tools, custom functions).
#     *   You define **edges** that dictate how the execution flows from one node to another, often based on conditional logic (e.g., "if the LLM decides to use a tool, go to the tool node; otherwise, go to the final response node").
#     *   It maintains a **state object** that is passed between nodes and updated by them, ensuring continuity and context.
#
# **In essence:**
#
# *   **LangChain provides the components:** The individual LLMs, tools, retrievers, and the basic `Runnable` interface to interact with them.
# *   **LangGraph provides the orchestration layer:** It's the framework that allows you to wire these LangChain components together into sophisticated, dynamic, and state-aware workflows, especially when you need cycles, complex branching, or multi-agent systems.
#
# You can think of LangChain as providing the individual LEGO bricks, and LangGraph as providing the blueprint and the advanced techniques to build a complex, interactive robot out of those bricks.
