# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.tools import Tool
from langchain_tavily import TavilySearch

# 🔑 GROQ & tavily API Key
GROQ_API_KEY = "provide your key"
tavily_api_key = "provide your key"

# 🔸 Initialize LLM
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=GROQ_API_KEY,
    temperature=0,
    max_tokens=300,
)

# ✅ Tool 1: Simple QA
qa_prompt = ChatPromptTemplate.from_template("Answer clearly: {question}")
qa_chain = qa_prompt|llm
qa_tool = Tool(
    name="Simple QA",
    func=qa_chain.invoke,
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer
summary_prompt = ChatPromptTemplate.from_template("Summarize the following text:\n\n{text}")
summary_chain = summary_prompt|llm
summary_tool = Tool(
    name="Summarizer",
    func=summary_chain.invoke,
    description="Summarizes input text"
)

# ✅ Tool 3: Web Search (Tavily)
tavily = TavilySearch(max_results=3,tavily_api_key=tavily_api_key)
search_tool = Tool(
    name="Web Search",
    func=tavily.invoke,
    description="Search the internet for current information"
)

# 🧪 Run each tool manually
qa_query = "What is LangGraph in LangChain?"
summary_text = """
LangGraph is a framework for building stateful multi-step agents using LangChain. 
It uses graph-based design to model agent workflows and memory.
"""
search_query = "Latest updates on GPT-4o by OpenAI"

print("\n🧠 Simple QA Tool Output:\n", qa_tool.invoke({"question": qa_query}))
print("\n📝 Summarizer Tool Output:\n", summary_tool.invoke({"text": summary_text}))
print("\n🌐 Web Search Tool Output:\n", search_tool.invoke(search_query))
# Out:
# 🧠 Simple QA Tool Output:
#  content='LangGraph is a core component of the LangChain framework. It is a knowledge graph that stores and manages the relationships between different pieces of information, such as entities, concepts, and relationships. \n\nIn LangChain, the LangGraph is used to represent the knowledge and context of a particular application or domain, and it serves as a central hub for storing and retrieving information. The LangGraph is designed to be flexible and scalable, allowing it to handle complex and dynamic knowledge representations.\n\nThe LangGraph is typically populated with data from various sources, such as text, databases, or other knowledge graphs. Once populated, the LangGraph can be used to support a wide range of applications, including question answering, text generation, and decision-making.\n\nSome key features of the LangGraph include:\n\n1. **Entity recognition**: The ability to identify and extract entities from text, such as names, locations, and organizations.\n2. **Relationship modeling**: The ability to model relationships between entities, such as "person A is a friend of person B".\n3. **Concept representation**: The ability to represent abstract concepts, such as ideas, events, and topics.\n4. **Inference and reasoning**: The ability to draw inferences and make logical deductions based on the information stored in the LangGraph.\n\nOverall, the LangGraph is a powerful tool for representing and managing complex knowledge, and it plays a central role in the LangChain framework.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 285, 'prompt_tokens': 46, 'total_tokens': 331, 'completion_time': 0.742729393, 'completion_tokens_details': None, 'prompt_time': 0.004188272, 'prompt_tokens_details': None, 'queue_time': 0.163782785, 'total_time': 0.746917665}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019daec1-2c2a-77d0-9722-03644865e898-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 46, 'output_tokens': 285, 'total_tokens': 331}
#
# 📝 Summarizer Tool Output:
#  content='LangGraph is a framework that uses a graph-based design to build multi-step agents with memory, utilizing the LangChain platform.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 71, 'total_tokens': 97, 'completion_time': 0.144061729, 'completion_tokens_details': None, 'prompt_time': 0.003497661, 'prompt_tokens_details': None, 'queue_time': 0.055876218, 'total_time': 0.14755939}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019daec1-30c8-75b1-b612-380f29f3b6c4-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 71, 'output_tokens': 26, 'total_tokens': 97}
#
# 🌐 Web Search Tool Output:
#  {'query': 'Latest updates on GPT-4o by OpenAI', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://help.openai.com/en/articles/9624314-model-release-notes', 'title': 'Model Release Notes - OpenAI Help Center', 'content': "Update to GPT-4o (April 29, 2025). We've reverted the most recent update to GPT-4o due to issues with overly agreeable responses (sycophancy).", 'score': 0.834852, 'raw_content': None}, {'url': 'https://community.openai.com/t/chatgpt-release-notes-2025-march-27-gpt-4o-a-new-update/1153887', 'title': 'ChatGPT — Release Notes: 2025-March-27 - GPT-4o a new update', 'content': 'GPT-4o feels more intuitive, creative, and collaborative · Follows instructions more accurately · Handles coding tasks more smoothly · Communicates', 'score': 0.796562, 'raw_content': None}, {'url': 'https://en.wikipedia.org/wiki/GPT-4o', 'title': 'GPT-4o - Wikipedia', 'content': 'OpenAI retired GPT-4o from ChatGPT on February 13, 2026. ... However, as of February 2026 the voice mode is still powered by GPT-4o or GPT-4o mini, depending on', 'score': 0.7451949, 'raw_content': None}], 'response_time': 0.61, 'request_id': '599c2f40-e549-46ae-b50d-b3b5ee815f3f'}

# %%
#!pip install -U langchain-tavily
# Out:
# Collecting langchain-tavily
#   Downloading langchain_tavily-0.2.18-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain-tavily) (3.13.5)
# Requirement already satisfied: langchain<2.0.0,>=1.0.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain-tavily) (1.2.15)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.11 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain-tavily) (1.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain-tavily) (2.33.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.23.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain<2.0.0,>=1.0.0->langchain-tavily) (1.1.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain<2.0.0,>=1.0.0->langchain-tavily) (2.13.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.7.32)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.0.10)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.25.0)
# Requirement already satisfied: anyio in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (4.13.0)
# Requirement already satisfied: certifi in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.0.9)
# Requirement already satisfied: idna in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (2.6.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\pavan\anaconda3\envs\langchain_env\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.3.1)
# Downloading langchain_tavily-0.2.18-py3-none-any.whl (30 kB)
# Installing collected packages: langchain-tavily
# Successfully installed langchain-tavily-0.2.18
