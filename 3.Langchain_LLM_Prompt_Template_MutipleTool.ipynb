# %%
import os
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.tools import Tool

# 🔑 GROQ API Key
GROQ_API_KEY = "provide your key"

# Initialize GROQ model
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=GROQ_API_KEY,
    temperature=0,
    max_tokens=300,
)

# ✅ Tool 1: Simple QA Tool
qa_prompt = ChatPromptTemplate.from_template("Answer clearly: {question}")
qa_chain = qa_prompt | llm
qa_tool = Tool(
    name="Simple QA",
    func=qa_chain.invoke,
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer Tool
summary_prompt = ChatPromptTemplate.from_template("Summarize the following text:\n\n{text}")
summary_chain = summary_prompt|llm
summary_tool = Tool(
    name="Summarizer",
    func=summary_chain.invoke,
    description="Summarizes input text"
)

# 🔧 Tool usage examples
qa_query = "What is LangGraph in LangChain?"
summary_text = """
LangGraph is a library built on top of LangChain that helps developers create stateful, multi-step agents 
as graphs. Each node represents a step like calling an LLM or a tool. It's ideal for advanced AI workflows.
"""

# 🚀 Run tools manually
print("\n🧠 Simple QA Tool Output:\n", qa_tool.invoke({"question": qa_query}))
print("\n📝 Summarizer Tool Output:\n", summary_tool.invoke({"text": summary_text}))
# Out:
# 🧠 Simple QA Tool Output:
#  content='LangGraph is a core component of the LangChain framework. It is a knowledge graph that represents the relationships between different pieces of information, such as entities, concepts, and relationships. \n\nIn LangChain, the LangGraph is used to store and manage the knowledge extracted from various sources, including text data, and to provide a structured representation of the information. This allows for more efficient and effective querying, reasoning, and generation of text based on the stored knowledge.\n\nThe LangGraph is essentially a graph database that uses nodes and edges to represent the relationships between different pieces of information. Nodes in the graph can represent entities, concepts, or other types of information, while edges represent the relationships between these nodes.\n\nBy using a graph structure to represent knowledge, LangGraph enables LangChain to perform complex queries and reasoning tasks, such as entity disambiguation, relationship extraction, and question answering. This makes it a powerful tool for natural language processing and generation tasks.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 192, 'prompt_tokens': 46, 'total_tokens': 238, 'completion_time': 1.6057832749999998, 'completion_tokens_details': None, 'prompt_time': 0.001429027, 'prompt_tokens_details': None, 'queue_time': 0.156789661, 'total_time': 1.607212302}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019daea5-d78b-7ac1-a3c0-759cbf233904-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 46, 'output_tokens': 192, 'total_tokens': 238}
#
# 📝 Summarizer Tool Output:
#  content='LangGraph is a library that helps developers create complex AI workflows by representing multi-step processes as graphs, with each node symbolizing a specific action, such as calling a language model or tool.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 89, 'total_tokens': 128, 'completion_time': 0.135326977, 'completion_tokens_details': None, 'prompt_time': 0.004492038, 'prompt_tokens_details': None, 'queue_time': 0.159255839, 'total_time': 0.139819015}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_4f6d808339', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019daea5-df71-7393-b608-c3518d5353c4-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 89, 'output_tokens': 39, 'total_tokens': 128}
